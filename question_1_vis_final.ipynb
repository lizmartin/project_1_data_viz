# %%
# Import libraries, dependencies
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Import our healthcare data into pandas from CSV (delete this cell when healthcare info code above is complete to directly create this df)
file_path = 'Resources/combined_data.csv'
denver_df = pd.read_csv(file_path, low_memory=False)

denver_df.head()
# Out:
#    Zip Code  Number of Facilities  Population  Per Capita Income  Median Age
# 0     80015                    43       70215              41860        37.6
# 1     80218                    42       18915              71825        34.9
# 2     80211                    42       36061              59034        34.0
# 3     80016                    37       58948              55122        38.5
# 4     80012                    35       53862              26477        32.8

# %%
#Create a double bar plot showing each zip code's number of facilities and population
#This example was very useful in creating the plot: https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/
x = denver_df['Zip Code']
facilities = denver_df['Number of Facilities']
pop = denver_df['Population'].div(1000)
pop = pop.values

x_axis = np.arange(len(x))
width = .3
fig = plt.figure(figsize=(15.5, 6))
plt.bar(x_axis - width/2, facilities, width = width, label = "Number of Facilities")


plt.bar(x_axis + width/2, pop, width = width, label = 'Population')
plt.axis([-1, len(x), 0, 80])
plt.xticks(x_axis, x, rotation=90)
plt.xlabel('Zip Code')
plt.ylabel('Number of Facilities or Population(in thousands)')
plt.title("Number of Facilities, Population by zip code")
plt.legend();

plt.savefig('pop_facilities_denver_plot.png')

# %%
#create a scatter plot Number of facilities vs Population
plt.scatter(pop, facilities)
plt.xlabel('Population (in thousands)')
plt.ylabel('Number of facilities')
plt.title('Number of facilities vs Population')

#perform a linear regression
pe_slope, pe_int, pe_r, pe_p, pe_std_err = stats.linregress(pop, facilities)
#create the equation of a line
pe_fit = pe_slope * pop + pe_int
plt.plot(pop, pe_fit)
plt.annotate(f'y={round(pe_slope, 2)}x + {round(pe_int, 2)}', (5,35), fontsize=15, color='red')
#print the correlation coefficient
corr = stats.pearsonr(pop,facilities)
print(f"The correlation coefficient between Population and Number of facilities is {round(corr[0],2)} \nThe p-value is {corr[1]}")
plt.savefig('pop_facilities_denver_scatter.png')
# Out:
# The correlation coefficient between Population and Number of facilities is 0.34
# The p-value is 0.001501650116741033

# %%
#read in detailed healthcare facility data frame
file_path = 'Resources/denver_healthcare_data.csv'
healthcare_df = pd.read_csv(file_path, low_memory=False)
healthcare_df.head()
# Out:
#    Unnamed: 0                               Facility Name  \
# 0           0  Presbyterian / Saint Luke's Medical Center
# 1           1                AdventHealth Parker Hospital
# 2           2                The Medical Center Of Aurora
# 3           3                   Porter Adventist Hospital
# 4           4                      Swedish Medical Center
#
#                                           Categories  Zipcode        Lat  \
# 0  ['building', 'building.healthcare', 'healthcar...  80218.0  39.747157
# 1              ['healthcare', 'healthcare.hospital']  80138.0  39.548590
# 2              ['healthcare', 'healthcare.hospital']  80012.0  39.690247
# 3              ['healthcare', 'healthcare.hospital']  80210.0  39.669970
# 4              ['healthcare', 'healthcare.hospital']  80113.0  39.654280
#
#           Lng
# 0 -104.967097
# 1 -104.769092
# 2 -104.832144
# 3 -104.975883
# 4 -104.981215

# %%
#Create a map of Denver healthcare facilities, colred according to categories
denver_h_map = healthcare_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    scale = 2,
    color = "Categories",
    hover_cols = ["Facility Name", "Zipcode"]
)

denver_h_map
# Out:
# Launching server at http://localhost:62444
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Categories,Facility Name,Zipcode)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1580', ...)

# %%
df = healthcare_df.dropna()
df = df.reset_index()
df = pd.DataFrame(df)
df = df.rename(columns={'Zipcode':'Zip Code'})
df['Zip Code'] = df['Zip Code'].astype('int64')
df = df.groupby(by='Zip Code').head(1).sort_values(by='Zip Code')

# %%
df_full = df.merge(denver_df)
df_full.head()
# Out:
#    index  Unnamed: 0       Facility Name  \
# 0    109         109   The Raleigh House
# 1     49          49  Bright Now! Dental
# 2    339         339          CSL Plasma
# 3    499         499           Walgreens
# 4    106         106      Comfort Dental
#
#                                           Categories  Zip Code        Lat  \
# 0                                     ['healthcare']     80002  39.789793
# 1               ['healthcare', 'healthcare.dentist']     80003  39.841056
# 2                                     ['healthcare']     80004  39.814088
# 3  ['commercial.health_and_beauty', 'commercial.h...     80007  39.811756
# 4               ['healthcare', 'healthcare.dentist']     80010  39.740555
#
#           Lng  Number of Facilities  Population  Per Capita Income  Median Age
# 0 -105.073198                     7       19319              41332        36.6
# 1 -105.081948                     7       36914              35063        36.3
# 2 -105.130489                     6       36118              41082        42.4
# 3 -105.169879                     3       16048              59539        38.2
# 4 -104.866804                     6       43653              20293        32.5

# %%
#Create a map of Denver Zip Codes(represented by the first facility in df in that zip code), colred according to Number of facilities and sized according to population

denver_p_map = df_full.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    scale = .05,
    size = "Population",
    color = "Number of Facilities",
    hover_cols = ["Zip Code", "Population", "Per Capita Income", "Median Age"]
)
denver_p_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Number of Facilities,Population,Zip Code,Per Capita Income,Median Age)
