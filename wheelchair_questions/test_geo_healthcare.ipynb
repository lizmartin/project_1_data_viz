# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Other imports
from api_key import geoapify_key

# %%
# Set the geographical coordinates for Denver, CO
latitude = 39.742043
longitude = -104.991531

# Set the search parameters to capture desired zipcodes
radius = 6500
limit = 20
filters = f"circle:{longitude},{latitude},{radius}"

# set up a parameters dictionary
params = {
    "categories": "healthcare",
    "filter":filters,
    "limit": limit,
    "apiKey":geoapify_key
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Empty list for data
health_facilities = []

# Retrieve the data with API request
print("Retrieving data...")
response = requests.get(base_url, params=params).json()


for feature in response["features"]:
    # Parse out facility name, categories, zipcode, lat, lng:
    fac_name = feature["properties"]["address_line1"]
    fac_type = feature["properties"]["categories"]
    fac_zip = feature["properties"]["postcode"]
    fac_lat = feature["properties"]["lat"]
    fac_lng = feature["properties"]["lon"]

    # Append the data into health_facilities list
    health_facilities.append({"Facility": fac_name,
                              "Categories": fac_type,
                              "Zipcode": fac_zip,
                              "Lat": fac_lat,
                              "Lng": fac_lng})
# Out:
# Retrieving data...

# %%
health_facilities_df = pd.DataFrame(health_facilities)

health_facilities_df
# Out:
#                                              Facility  \
# 0          Presbyterian / Saint Luke's Medical Center
# 1                        Denver Health Medical Center
# 2                       HealthOne Rose Medical Center
# 3                      Park Hill Family Health Center
# 4          Children's Hospital Colorado Uptown Denver
# 5                              National Jewish Health
# 6              Denver Veterans Affairs Medical Center
# 7      Children's Hospital Colorado KidStreet, Denver
# 8         Denver Health Eastside Family Health Center
# 9   Denver Health Medical Center Emergency Departm...
# 10  Denver Health Medical Emergency Center for Chi...
# 11                Planned Parenthood (Denver Central)
# 12                                       King Soopers
# 13           Sam Sandos Westside Family Health Center
# 14                   SCL Health Saint Joseph Hospital
# 15           Jing Japanese Acupuncture - Patti Polman
# 16                            Vision Care Specialists
# 17                                        Ritualcravt
# 18                                        PrimeHealth
# 19                                    AFC Urgent Care
#
#                                            Categories Zipcode        Lat  \
# 0   [building, building.healthcare, healthcare, he...   80218  39.747157
# 1                   [healthcare, healthcare.hospital]   80204  39.727328
# 2                   [healthcare, healthcare.hospital]   80220  39.731637
# 3   [building, building.commercial, building.healt...   80207  39.764086
# 4   [building, building.healthcare, healthcare, he...   80218  39.745185
# 5   [healthcare, healthcare.hospital, wheelchair, ...   80206  39.739210
# 6                   [healthcare, healthcare.hospital]   80220  39.732418
# 7           [healthcare, healthcare.clinic_or_praxis]   80205  39.762597
# 8           [healthcare, healthcare.clinic_or_praxis]   80205  39.755596
# 9                   [healthcare, healthcare.hospital]   80204  39.728464
# 10  [healthcare, healthcare.clinic_or_praxis.paedi...   80204  39.727656
# 11          [healthcare, healthcare.clinic_or_praxis]   80218  39.738641
# 12  [commercial.health_and_beauty, commercial.heal...   80204  39.737403
# 13          [healthcare, healthcare.clinic_or_praxis]   80204  39.734421
# 14                  [healthcare, healthcare.hospital]   80218  39.746176
# 15                                       [healthcare]   80211  39.776877
# 16                                       [healthcare]   80265  39.747944
# 17                                       [healthcare]   80211  39.776492
# 18          [healthcare, healthcare.clinic_or_praxis]   80202  39.742170
# 19          [healthcare, healthcare.clinic_or_praxis]   80246  39.702745
#
#            Lng
# 0  -104.967097
# 1  -104.991208
# 2  -104.933408
# 3  -104.929686
# 4  -104.967840
# 5  -104.942378
# 6  -104.936325
# 7  -104.944210
# 8  -104.975692
# 9  -104.990709
# 10 -104.991082
# 11 -104.975779
# 12 -104.998399
# 13 -105.024256
# 14 -104.971086
# 15 -105.034462
# 16 -104.994164
# 17 -105.023346
# 18 -104.987057
# 19 -104.940246

# %%
# get location and count of facilities
