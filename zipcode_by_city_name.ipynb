# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Other imports
from api_key import geoapify_key

# %%
# Target city
target_city = "Denver, United States"

# Build the endpoint URL
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "query": {
#         "parsed": {
#             "city": "denver",
#             "country": "united states",
#             "expected_type": "city"
#         },
#         "text": "Denver, United States"
#     },
#     "results": [
#         {
#             "address_line1": "Denver, CO",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 39.6143008,
#                 "lat2": 39.9142087,
#                 "lon1": -105.1098845,
#                 "lon2": -104.5996997
#             },
#             "category": "administrative",
#             "city": "Denver",
#             "country": "United States",
#             "country_code": "us",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Denver, CO, United States of America",
#             "lat": 39.7392364,
#             "lon": -104.984862,
#             "place_id": "51af44a0fa073f5ac059a301614c9fde4340f00101f9010b89150000000000c00208",
#             "plus_code": "85FQP2Q8+M3",
#             "plus_code_short": "+M3 Denver, Colorado, United States",
#             "rank": {
#                 "confidence": 1,
#                 "confidence_city_level": 1,
#                 "importance": 0.8954758739095791,
#                 "match_type": "full_match",
#                 "popularity": 7.788395696980934
#             },
#             "result_type": "city",
#             "state": "Colorado",
#             "state_code": "CO",
#             "timezone": {
#                 "abbreviation_DST": "MDT",
#                 "abbreviation_STD": "MST",
#                 "name": "America/Denver",
#                 "offset_DST": "-06:00",
#                 "offset_DST_seconds": -21600,
#                 "offset_STD": "-07:00",
#                 "offset_STD_seconds": -25200
#             }
#         },
#         {
#             "address_line1": "Denver, IN",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 40.8587,
#                 "lat2": 40.8692313,
#                 "lon1": -86.0843217,
#                 "lon2": -86.0718823
#             },
#             "category": "administrative",
#             "city": "Denver",
#             "country": "United States",
#             "country_code": "us",
#             "county": "Miami County",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Denver, IN, United States of America",
#             "lat": 40.8638698,
#             "lon": -86.0775009,
#             "place_id": "5147ba55c6f58455c05944801d49936e4440f00101f9010711dc0000000000c00208",
#             "plus_code": "86GMVW7C+GX",
#             "rank": {
#                 "confidence": 1,
#                 "confidence_city_level": 1,
#                 "importance": 0.6562810930352119,
#                 "match_type": "full_match",
#                 "popularity": 1.7611415590569635
#             },
#             "result_type": "city",
#             "state": "Indiana",
#             "state_code": "IN",
#             "timezone": {
#                 "abbreviation_DST": "EDT",
#                 "abbreviation_STD": "EST",
#                 "name": "America/Indiana/Indianapolis",
#                 "offset_DST": "-04:00",
#                 "offset_DST_seconds": -14400,
#                 "offset_STD": "-05:00",
#                 "offset_STD_seconds": -18000
#             }
#         },
#         {
#             "address_line1": "Denver (Denver), PA",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 40.2211145,
#                 "lat2": 40.2467921,
#                 "lon1": -76.1585778,
#                 "lon2": -76.1248465
#             },
#             "borough": "Denver",
#             "category": "administrative",
#             "city": "Denver",
#             "country": "United States",
#             "country_code": "us",
#             "county": "Lancaster County",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Denver (Denver), PA, United States of America",
#             "lat": 40.2331483,
#             "lon": -76.1371684,
#             "place_id": "51db02f85dc70853c0591bcfb1cdd71d4440f00101f90133dd020000000000c00208",
#             "plus_code": "87G56VM7+74",
#             "plus_code_short": "+74 Denver, Lancaster County, United States",
#             "rank": {
#                 "confidence": 1,
#                 "confidence_city_level": 1,
#                 "importance": 0.6265480119372578,
#                 "match_type": "full_match",
#                 "popularity": 2.5730272650182933
#             },
#             "result_type": "city",
#             "state": "Pennsylvania",
#             "state_code": "PA",
#             "timezone": {
#                 "abbreviation_DST": "EDT",
#                 "abbreviation_STD": "EST",
#                 "name": "America/New_York",
#                 "offset_DST": "-04:00",
#                 "offset_DST_seconds": -14400,
#                 "offset_STD": "-05:00",
#                 "offset_STD_seconds": -18000
#             }
#         },
#         {
#             "address_line1": "Denver, MO",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 40.391698,
#                 "lat2": 40.405941,
#                 "lon1": -94.329049,
#                 "lon2": -94.31875
#             },
#             "category": "administrative",
#             "city": "Denver",
#             "country": "United States",
#             "country_code": "us",
#             "county": "Worth County",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Denver, MO, United States of America",
#             "lat": 40.397202,
#             "lon": -94.324604,
#             "place_id": "51a609db4fc69457c059f1f3df83d7324440f00101f9012028020000000000c00208",
#             "plus_code": "86G79MWG+V5",
#             "rank": {
#                 "confidence": 1,
#                 "confidence_city_level": 1,
#                 "importance": 0.5745321115064418,
#                 "match_type": "full_match",
#                 "popularity": 1.124648170706878
#             },
#             "result_type": "city",
#             "state": "Missouri",
#             "state_code": "MO",
#             "timezone": {
#                 "abbreviation_DST": "CDT",
#                 "abbreviation_STD": "CST",
#                 "name": "America/Chicago",
#                 "offset_DST": "-05:00",
#                 "offset_DST_seconds": -18000,
#                 "offset_STD": "-06:00",
#                 "offset_STD_seconds": -21600
#             }
#         },
#         {
#             "address_line1": "Denver, IA 50622",
#             "address_line2": "United States of America",
#             "bbox": {
#                 "lat1": 42.6567999,
#                 "lat2": 42.6803073,
#                 "lon1": -92.3471364,
#                 "lon2": -92.317541
#             },
#             "category": "administrative",
#             "city": "Denver",
#             "country": "United States",
#             "country_code": "us",
#             "county": "Bremer County",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Denver, IA 50622, United States of America",
#             "lat": 42.6713752,
#             "lon": -92.3372158,
#             "place_id": "51722c94f1941557c05938ac5f9fef554540f00101f90100f6010000000000c00207",
#             "plus_code": "86J9MMC7+H4",
#             "plus_code_short": "+H4, 50622 Denver, United States",
#             "postcode": "50622",
#             "rank": {
#                 "confidence": 1,
#                 "confidence_city_level": 1,
#                 "importance": 0.7318394385017,
#                 "match_type": "full_match",
#                 "popularity": 1.1104852988164589
#             },
#             "result_type": "postcode",
#             "state": "Iowa",
#             "state_code": "IA",
#             "timezone": {
#                 "abbreviation_DST": "CDT",
#                 "abbreviation_STD": "CST",
#                 "name": "America/Chicago",
#                 "offset_DST": "-05:00",
#                 "offset_DST_seconds": -18000,
#                 "offset_STD": "-06:00",
#                 "offset_STD_seconds": -21600
#             }
#         }
#     ]
# }
